# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import numpy as np

# %%
data = load_breast_cancer()
feature_names = data.feature_names
data_points = data.data
print(data.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %%
df = pd.DataFrame(data_points, columns=feature_names)

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension           ...             worst radius  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(data_points, data.target, test_size=0.20, random_state=42)

# %%
ada_clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), n_estimators=200, algorithm="SAMME.R", learning_rate=0.5)

# %%
ada_clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=0.5, n_estimators=200, random_state=None)

# %%
preds = ada_clf.predict(X_test)

# %%
results = []
for x in range(10, 200, 10):
    ada_clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), n_estimators=x, algorithm="SAMME.R", learning_rate=0.5)
    ada_clf.fit(X_train, y_train)
    preds = ada_clf.predict(X_test)   
    results.append([x, metrics.accuracy_score(y_test, preds), metrics.precision_score(y_test, preds), metrics.recall_score(y_test, preds)])

# %%
X =  [ x for x, _, _, _ in results ]
accuracy =  [ y for x, y, _, _ in results ]
precision =  [ y for x, _, y, _ in results ]
recall     = [ y for x, _, _, y in results  ]

font = {'family' : 'normal','weight' : 'bold','size'   : 22}
plt.rcParams.update({'font.size': 15})
plt.figure(figsize=(15,6))
plt.plot(X, accuracy)
plt.plot(X, precision)
plt.plot(X, recall)
plt.legend(['y = accuracy', 'y = precision', 'y = recall'], loc='upper left')

# %%
results = []
for x in range(24):
    ada_clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=x + 1), n_estimators=200, algorithm="SAMME.R", learning_rate=0.5)
    ada_clf.fit(X_train, y_train)
    preds = ada_clf.predict(X_test)   
    results.append([x, metrics.accuracy_score(y_test, preds), metrics.precision_score(y_test, preds), metrics.recall_score(y_test, preds)])

# %%
X =  [ x for x, _, _, _ in results ]
accuracy =  [ y for x, y, _, _ in results ]
precision =  [ y for x, _, y, _ in results ]
recall     = [ y for x, _, _, y in results  ]

font = {'family' : 'normal','weight' : 'bold','size'   : 22}
plt.rcParams.update({'font.size': 15})
plt.figure(figsize=(15,6))
plt.plot(X, accuracy)
plt.plot(X, precision)
plt.plot(X, recall)
plt.legend(['y = accuracy', 'y = precision', 'y = recall'], loc='upper left')

# %% [markdown]
# # Linear model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing

# %%
scalar = preprocessing.StandardScaler().fit(X_train)
X_transformed = scaler.transform(X_train)
log_reg = LogisticRegression()
log_reg.fit(X_transformed, y_train)


X_test_trans = scalar.transform(X_test)
preds = log_reg.predict(X_test_trans)

# %%
print(classification_report(preds, y_test))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96        42
#           1       0.99      0.97      0.98        72
#
# avg / total       0.97      0.97      0.97       114

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

confusion_matrix(preds, y_test).ravel()
print(classification_report(preds, y_test))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.91      0.97      0.94        40
#           1       0.99      0.95      0.97        74
#
# avg / total       0.96      0.96      0.96       114

# %% [markdown]
# # Bayesian Logistic Regression

# %%
import pymc3 as pm
import seaborn
print(X_train.shape)
# Out:
# (455, 30)

# %%
df = pd.DataFrame(X_train[:, :6], columns=feature_names[:6]) 
seaborn.pairplot(df)

# %%
scalar = preprocessing.StandardScaler().fit(X_train)
X_transformed = scaler.transform(X_train)
X_test_trans = scalar.transform(X_test)
print(zcoeffs.shape)
# Out:
# Shape.0

# %%
num = 50

print(pm.math.invlogit(num).eval())
print(pm.math.sigmoid(num).eval())
# Out:
# 0.9999999999999998
# 1.0

# %%
with pm.Model() as model:
    zcoeffs = pm.Normal("zcoeffs", mu=0, sd=12, shape=len(feature_names))
    zintercept =  pm.Normal("zintercept", mu=0, sd=12)
    
    probability = pm.math.invlogit(zintercept + ( zcoeffs * X_transformed ).sum(axis=1) )

    pm.Bernoulli("obs", probability, observed=y_train)
    trace = pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [zintercept, zcoeffs]
# Sampling 2 chains: 100%|██████████| 21000/21000 [06:03<00:00, 57.74draws/s]
# There were 46 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 53 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x153bceb00>,
# ...
#       dtype=object)

# %%
start = 3000
stop  = len(trace)
step  = int(len(trace) / 100)
print("start {} stop {} step {}".format(start, stop, step))
intercepts = trace['zintercept'][start:stop:step]
coeffs     = trace['zcoeffs'][start:stop:step]
# Out:
# start 3000 stop 20000 step 200

# %%
0 ^ 1
# Out:
# 1

# %%
print(y_test[20])
log_reg.predict_proba(scalar.transform(X_test[20].reshape(1, -1)))
# Out:
# 0
# array([[0.08935574, 0.91064426]])

# %%
for i in range(2, 3):
    data = scalar.transform(X_test[i].reshape(1, -1)).reshape(-1)
    results = pm.math.sigmoid(intercepts + (coeffs * data).sum(axis=1)).eval()
    plt.hist(results, bins=np.arange(0, 1.1, 0.05))

    plt.xlabel("logistic value")
    plt.title("Actual value: {}".format(y_train[i]))
    plt.show()
# Out:
# INFO (theano.gof.compilelock): Refreshing lock /Users/jamesvanneman/.theano/compiledir_Darwin-18.0.0-x86_64-i386-64bit-i386-3.6.4-64/lock_dir/lock
